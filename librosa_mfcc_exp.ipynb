# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as w

#sr,x=w.read('o_o3.wav')
x,sr=(librosa.core.load('o1.wav',sr=None))
print x,sr
mfccs = librosa.feature.mfcc(y=x, sr=24000, n_mfcc=50)
print mfccs.shape
plt.pcolormesh(mfccs, cmap='hot')
plt.show()
print mfccs[:,0].size
print mfccs[:,0]
# Out:
# [ 0.          0.5        -0.86602783 ..., -1.          0.86602783 -0.5       ] 24000
# (50, 938)
# 50
# [-196.69506329  -66.52831657   49.48143251  -36.13603837   26.42956106
#   -19.44705624   13.95575227   -9.59580328    5.95833285   -2.92506189
#     0.30716634    1.87172069   -3.74428919    5.25890612   -6.54312004
#     7.50603931   -8.24966292    8.71055959   -9.00030185    9.03265512
#    -8.90834194    8.56597106   -8.13212701    7.50195417   -6.78653716
#     5.94288995   -5.08298076    4.11502187   -3.16685094    2.15577196
#    -1.21366863    0.25678513    0.62239374   -1.4843962     2.18804331
#    -2.88092806    3.4394356    -3.92018934    4.23329694   -4.5146011
#     4.62114836   -4.66323539    4.54500744   -4.4074009     4.10948081
#    -3.78837712    3.34180035   -2.89883362    2.34711728   -1.85781792]

# %%
S = librosa.feature.melspectrogram(y=x, sr=sr, n_mels=50, fmax=12000)
print S.shape
plt.pcolormesh(S)
plt.show()
# Out:
# (50, 1876)
