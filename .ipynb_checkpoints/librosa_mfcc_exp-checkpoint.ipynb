# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as w

#sr,x=w.read('o_o3.wav')
x,sr=(librosa.core.load('o1.wav',sr=24000))
print x,sr
mfccs = librosa.feature.mfcc(y=x, sr=24000, n_mfcc=50)
print mfccs.shape
plt.pcolormesh(mfccs, cmap='hot')
plt.show()
print mfccs[:,0].size
print mfccs[:,0]
# Out:
# [1859775393 2100555978 2135719508 ...,  -37486592  -13172736  -15400960] 24000
# (50, 2344)
# 50
# [  2.01177167e+03   1.54443277e+02  -5.83522773e+01  -4.50233596e+01
#   -1.69161820e+01   1.93114135e+01   2.37327231e+01   6.68260920e+00
#   -1.34091577e+01  -1.59343188e+01  -3.08270090e+00   1.08461255e+01
#    1.17737772e+01   1.12206735e+00  -9.38870845e+00  -9.19347180e+00
#    5.71734166e-02   8.31394250e+00   7.31366758e+00  -9.14033156e-01
#   -7.52133639e+00  -5.92570678e+00   1.48775484e+00   6.81153692e+00
#    4.76437358e+00  -1.96272819e+00  -6.22998826e+00  -3.84100565e+00
#    2.26504116e+00   5.65207410e+00   3.01779323e+00  -2.53209445e+00
#   -5.16837222e+00  -2.35694712e+00   2.67621848e+00   4.66747528e+00
#    1.73335848e+00  -2.81949528e+00  -4.24566402e+00  -1.23583858e+00
#    2.85714949e+00   3.78450364e+00   7.49764999e-01  -2.90826725e+00
#   -3.40404179e+00  -3.84771804e-01   2.85646273e+00   2.98685285e+00
#    7.49360055e-03  -2.84890568e+00]

# %%
S = librosa.feature.melspectrogram(y=x, sr=sr, n_mels=50, fmax=12000)
print S.shape
plt.pcolormesh(S)
plt.show()
# Out:
# (50, 1876)
